# %% [markdown]
# # Matplotlib.pyplot.subplots()
#     subplots():provides a way to plot multiple plot on single figure.
#     Given number of rows and columns. It returns a tupple (fig,ax) giving a single figure fig with an array of axes ax.

# %%
import matplotlib.pyplot as plt

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))

# %%
import numpy as np

# %%
sales_data={'Electronics':45000,'Clothing':30000,'Grocery':25000,'Mobile':20000}
category=list(sales_data.keys())
actual_sale=list(sales_data.values())
print(category)
print(actual_sale)
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
x=np.random.random(10)
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(category,actual_sale)
ax4.hist(np.random.randn(1000))
# Out:
# ['Electronics', 'Clothing', 'Grocery', 'Mobile']
# [45000, 30000, 25000, 20000]
# (array([ 12.,  42., 146., 250., 270., 192.,  68.,  16.,   3.,   1.]),
#  array([-3.04583443, -2.32354985, -1.60126527, -0.87898068, -0.1566961 ,
#          0.56558848,  1.28787306,  2.01015764,  2.73244222,  3.45472681,
#          4.17701139]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Subplots using indexing

# %%
our_lines=np.linspace(0,10,100)

# %%
product_prices={'Hair Oil':20, 'Face Wash':30, 'Lip Balm':10, 'Face cream':15}

# %%
our_numbers=np.random.random(10)

# %%
our_dots=np.random.randn(1000)

# %%
# ax[0,0] =ax1 (atas kanan)
# ac[0,1] =ax2 (atas kiri)
# ax[1,0] =ax3 (bawah kanan)
# ax[1,1] =ax4 (bawah kiri)

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(8,5))
ax[0,0].plot(our_lines,our_lines/2) 
ax[0,1].bar(list(product_prices.keys()),list(product_prices.values()),color=['blue','green','red','orange'])
ax[1,0].scatter(np.random.randn(100),np.random.randn(100),color='orange')
ax[1,1].hist(our_dots,color='red')
# first row 0 & first column 0 means {0,0] Line Plot
#--------------------------------------------------------------
ax[0,0].set_title('Line Plot Example')
ax[0,0].set_xlabel('X Axis')
ax[0,0].set_ylabel('Y Axis')
ax[0,0].grid(True,linestyle='--', alpha=0.7, color='black', axis='y')
# first row 0 & second column 1 means [0,1] Bar plot
#---------------------------------------------------------------
ax[0,1].set_title('Product Sales Information')
ax[0,1].set_xlabel('Product Name')
ax[0,1].set_ylabel('Product Sales')
ax[0,1].grid(True,linestyle='--', alpha=0.7, color='purple', axis='y')
#----------------------------------------------------------------
ax[1,0].set_title('Our Scatter Plot')
ax[1,0].set_xlabel('Product Name')
ax[1,0].set_ylabel('Product Sales')
ax[1,0].grid(True,linestyle='--', alpha=0.7, color='red')

ax[1,1].set_title('Histogram Example')
ax[1,1].set_xlabel('Value Range')
ax[1,1].set_ylabel('Frequency')
ax[1,1].grid(True,linestyle='--', alpha=0.7, color='red')

fig.suptitle('Matplot Lib SubPlots example using 2 rows and 2 cols')
plt.tight_layout()
plt.savefig('subplotex.jpeg',dpi=300,bbox_inches='tight')
